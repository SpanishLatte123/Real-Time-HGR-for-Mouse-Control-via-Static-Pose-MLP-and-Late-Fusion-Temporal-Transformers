# %% [markdown]
# ### Temporal Transformers Trainer
# This notebook Builds the Temporal Transformer Model as the main Dynamic Gestures Classifier

# %%
import numpy as np
import os
import keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import layers

os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %% [markdown]
# #### Concatenate Batch Files

# %%
def concatenate_files_from_folders(folder_paths):
    arrays = []
    for folder_path in folder_paths:
            # List all .npy files in the folder
            for file_name in os.listdir(folder_path):
                if file_name.endswith('.npy') and file_name!='seq_D0X_full.npy':
                    file_path = os.path.join(folder_path, file_name)
                    # Load the .npy file and append it to the list
                    arrays.append(np.load(file_path))
    # Concatenate all arrays along the first axis
    concatenated_data = np.concatenate(arrays, axis=0)
    return concatenated_data

# %%
folder_1 = 'Dataset/Batch1/seq_skeleton'
folder_2 = 'Dataset/Batch2/seq_skeleton'
folder_3 = 'Dataset/Batch3/seq_skeleton'

# %%
data = concatenate_files_from_folders([folder_1, folder_2,folder_3])

# %% [markdown]
# #### Extract Data and Do Train Test Split

# %%
#extracting data
x_data = data[:, :, :-1]
labels = data[:, 0, -1]
y_data = labels
x_data = x_data.astype(np.float32)
y_data = y_data.astype(np.float32)
#train test splot
x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size=0.1, random_state=2024)

# %%
x_train.shape
# Out:
# (315949, 65, 99)

# %% [markdown]
# #### Define Temporal Transformer

# %%
input_shape = (65,99)
n_classes = 13
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %% [markdown]
# #### Build Transformer Model
# We scale our transformer model by specifying the transformer blocks cascaded and mlp units per block

# %%
model = build_model(
    input_shape,
    head_size=128,
    num_heads=4,
    ff_dim=128,
    num_transformer_blocks=3,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["sparse_categorical_accuracy"],
)
model.summary()
keras.utils.plot_model(model, to_file='figures/plot_model_NoD0X.png', show_shapes=True, show_layer_names=True, dpi=100)
callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 65, 99)]             0         []
#
#  multi_head_attention_4 (Mu  (None, 65, 99)               204387    ['input_3[0][0]',
#  ltiHeadAttention)                                                   'input_3[0][0]']
#
#  dropout_10 (Dropout)        (None, 65, 99)               0         ['multi_head_attention_4[0][0]
#                                                                     ']
#
#  layer_normalization_8 (Lay  (None, 65, 99)               198       ['dropout_10[0][0]']
#  erNormalization)
#
#  tf.__operators__.add_8 (TF  (None, 65, 99)               0         ['layer_normalization_8[0][0]'
#  OpLambda)                                                          , 'input_3[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 65, 128)              12800     ['tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  dropout_11 (Dropout)        (None, 65, 128)              0         ['conv1d_8[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 65, 99)               12771     ['dropout_11[0][0]']
#
#  layer_normalization_9 (Lay  (None, 65, 99)               198       ['conv1d_9[0][0]']
#  erNormalization)
#
#  tf.__operators__.add_9 (TF  (None, 65, 99)               0         ['layer_normalization_9[0][0]'
#  OpLambda)                                                          , 'tf.__operators__.add_8[0][0
#                                                                     ]']
#
#  multi_head_attention_5 (Mu  (None, 65, 99)               204387    ['tf.__operators__.add_9[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 65, 99)               0         ['multi_head_attention_5[0][0]
#                                                                     ']
#
#  layer_normalization_10 (La  (None, 65, 99)               198       ['dropout_12[0][0]']
#  yerNormalization)
#
#  tf.__operators__.add_10 (T  (None, 65, 99)               0         ['layer_normalization_10[0][0]
#  FOpLambda)                                                         ',
#                                                                      'tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  conv1d_10 (Conv1D)          (None, 65, 128)              12800     ['tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  dropout_13 (Dropout)        (None, 65, 128)              0         ['conv1d_10[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 65, 99)               12771     ['dropout_13[0][0]']
#
#  layer_normalization_11 (La  (None, 65, 99)               198       ['conv1d_11[0][0]']
#  yerNormalization)
#
#  tf.__operators__.add_11 (T  (None, 65, 99)               0         ['layer_normalization_11[0][0]
#  FOpLambda)                                                         ',
#                                                                      'tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  multi_head_attention_6 (Mu  (None, 65, 99)               204387    ['tf.__operators__.add_11[0][0
#  ltiHeadAttention)                                                  ]',
#                                                                      'tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  dropout_14 (Dropout)        (None, 65, 99)               0         ['multi_head_attention_6[0][0]
#                                                                     ']
#
#  layer_normalization_12 (La  (None, 65, 99)               198       ['dropout_14[0][0]']
#  yerNormalization)
#
#  tf.__operators__.add_12 (T  (None, 65, 99)               0         ['layer_normalization_12[0][0]
#  FOpLambda)                                                         ',
#                                                                      'tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  conv1d_12 (Conv1D)          (None, 65, 128)              12800     ['tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  dropout_15 (Dropout)        (None, 65, 128)              0         ['conv1d_12[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 65, 99)               12771     ['dropout_15[0][0]']
#
#  layer_normalization_13 (La  (None, 65, 99)               198       ['conv1d_13[0][0]']
#  yerNormalization)
#
#  tf.__operators__.add_13 (T  (None, 65, 99)               0         ['layer_normalization_13[0][0]
#  FOpLambda)                                                         ',
#                                                                      'tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  global_average_pooling1d_2  (None, 99)                   0         ['tf.__operators__.add_13[0][0
#   (GlobalAveragePooling1D)                                          ]']
#
#  dense_4 (Dense)             (None, 128)                  12800     ['global_average_pooling1d_2[0
#                                                                     ][0]']
#
#  dropout_16 (Dropout)        (None, 128)                  0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 13)                   1677      ['dropout_16[0][0]']
#
# ==================================================================================================
# Total params: 705539 (2.69 MB)
# Trainable params: 705539 (2.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train

# %%
history = model.fit(
    x_train,
    y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    callbacks=[
        ModelCheckpoint("Trained Models/dynamic/1_temporal_transformer_quad_noD0X.h5", monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='auto'),
        ReduceLROnPlateau(monitor='val_sparse_categorical_accuracy', factor=0.5, patience=10, verbose=1, mode='auto')
    ]
)
# Out:
# Epoch 1/5
# 9874/9874 [==============================] - ETA: 0s - loss: 0.8617 - sparse_categorical_accuracy: 0.8681
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.94206, saving model to Trained Models/dynamic\1_temporal_transformer_quad_noD0X.h5
# c:\Users\Christian\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 9874/9874 [==============================] - 1644s 166ms/step - loss: 0.8617 - sparse_categorical_accuracy: 0.8681 - val_loss: 0.1471 - val_sparse_categorical_accuracy: 0.9421 - lr: 1.0000e-04
# Epoch 2/5
# 9874/9874 [==============================] - ETA: 0s - loss: 0.1493 - sparse_categorical_accuracy: 0.9423
# Epoch 2: val_sparse_categorical_accuracy improved from 0.94206 to 0.95246, saving model to Trained Models/dynamic\1_temporal_transformer_quad_noD0X.h5
# 9874/9874 [==============================] - 1517s 154ms/step - loss: 0.1493 - sparse_categorical_accuracy: 0.9423 - val_loss: 0.1158 - val_sparse_categorical_accuracy: 0.9525 - lr: 1.0000e-04
# Epoch 3/5
# 9874/9874 [==============================] - ETA: 0s - loss: 0.1066 - sparse_categorical_accuracy: 0.9577
# Epoch 3: val_sparse_categorical_accuracy improved from 0.95246 to 0.96553, saving model to Trained Models/dynamic\1_temporal_transformer_quad_noD0X.h5
# 9874/9874 [==============================] - 1604s 162ms/step - loss: 0.1066 - sparse_categorical_accuracy: 0.9577 - val_loss: 0.0848 - val_sparse_categorical_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 4/5
# 9874/9874 [==============================] - ETA: 0s - loss: 0.0840 - sparse_categorical_accuracy: 0.9670
# Epoch 4: val_sparse_categorical_accuracy improved from 0.96553 to 0.97884, saving model to Trained Models/dynamic\1_temporal_transformer_quad_noD0X.h5
# 9874/9874 [==============================] - 1539s 156ms/step - loss: 0.0840 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0530 - val_sparse_categorical_accuracy: 0.9788 - lr: 1.0000e-04
# Epoch 5/5
# 9874/9874 [==============================] - ETA: 0s - loss: 0.0683 - sparse_categorical_accuracy: 0.9736
# Epoch 5: val_sparse_categorical_accuracy improved from 0.97884 to 0.98442, saving model to Trained Models/dynamic\1_temporal_transformer_quad_noD0X.h5
# 9874/9874 [==============================] - 1510s 153ms/step - loss: 0.0683 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0375 - val_sparse_categorical_accuracy: 0.9844 - lr: 1.0000e-04

# %% [markdown]
# ### Plot Train History

# %%
#printing results
import matplotlib.pyplot as plt
# %matplotlib inline

fig, loss_ax = plt.subplots(figsize=(16, 10))
acc_ax = loss_ax.twinx()

acc_ax.plot(history.history['sparse_categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(history.history['val_sparse_categorical_accuracy'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')

plt.title('Single_Stack_Temporal_Transformer: Acc - 0.94927')

plt.show()

# %%
import seaborn as sns
from sklearn import metrics


# Define the actions (class names)
actions = ['G01', 'G02', 'G03', 'G04', 'G05', 'G06', 'G07', 'G08', 'G09', 'G10', 'G11', 'B0A', 'B0B', 'D0X']

# Predict the classes
Y_pred = model.predict(x_val)
Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_true = y_val

# Compute the confusion matrix
confusion_mtx = metrics.confusion_matrix(Y_true, Y_pred_classes, normalize='true')

# Plot the confusion matrix
f, ax = plt.subplots(figsize=(10, 10))  # Adjusted the size for better readability
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01, cmap="Greens", linecolor="gray", fmt='.2f', 
            xticklabels=actions, yticklabels=actions, ax=ax)

# Set axis labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title('Single_Stack_Temporal_Transformer No D0X')
plt.xticks(rotation=45)  # Rotate the x labels for better readability
plt.yticks(rotation=0)
plt.savefig('Figures/Single_Stack_Temporal_Transformer_0.94927.jpg')

# Show the plot
plt.show()
# Out:
# 1098/1098 [==============================] - 56s 50ms/step
