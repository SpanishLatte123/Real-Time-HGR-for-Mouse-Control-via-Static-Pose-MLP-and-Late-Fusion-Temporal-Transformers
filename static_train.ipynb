# %%
from static_model.static_model import ClassificationModel
import os

# %%
path_to_model = os.path.join(os.getcwd(), "Trained Models\static\static_model_pass2.h5")
path_to_data = os.path.join(os.getcwd(), "Static_Dataset\static_dataset_1")
hidden_layers = (50,25,10)
learning_rate = 0.01
epochs = 15
test_size = 0.3

# Train the model
model = ClassificationModel()
model.read_dataset(path_to_data)
model.process_dataset()
model.train(hidden_layers=hidden_layers,
            learning_rate=learning_rate,
            epochs=epochs,
            test_size=test_size)
model.save_model(path_to_model)
# Out:
# Epoch 1/15
# 44/44 - 1s - loss: 0.5671 - accuracy: 0.8341 - val_loss: 0.0643 - val_accuracy: 0.9882 - 621ms/epoch - 14ms/step
# Epoch 2/15
# 44/44 - 0s - loss: 0.0636 - accuracy: 0.9784 - val_loss: 0.0327 - val_accuracy: 0.9933 - 76ms/epoch - 2ms/step
# Epoch 3/15
# 44/44 - 0s - loss: 0.0423 - accuracy: 0.9863 - val_loss: 0.0399 - val_accuracy: 0.9899 - 74ms/epoch - 2ms/step
# Epoch 4/15
# 44/44 - 0s - loss: 0.0260 - accuracy: 0.9892 - val_loss: 0.0199 - val_accuracy: 0.9949 - 77ms/epoch - 2ms/step
# Epoch 5/15
# 44/44 - 0s - loss: 0.0275 - accuracy: 0.9906 - val_loss: 0.0109 - val_accuracy: 0.9933 - 78ms/epoch - 2ms/step
# Epoch 6/15
# 44/44 - 0s - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.0092 - val_accuracy: 0.9949 - 77ms/epoch - 2ms/step
# Epoch 7/15
# 44/44 - 0s - loss: 0.0286 - accuracy: 0.9885 - val_loss: 0.0148 - val_accuracy: 0.9966 - 70ms/epoch - 2ms/step
# Epoch 8/15
# ...
